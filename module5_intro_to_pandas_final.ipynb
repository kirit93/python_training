# %%
import pandas as pd

# %%
csv_file_path = './data/sales_data_all.csv'
sales_df = pd.read_csv(csv_file_path)

# To view the first 5 rows of the populated dataframe, we use the .head() function
sales_df.head()
# Out:
#   order_date  stock_date order_number  product_key  customer_key  \
# 0   1/1/2015   9/21/2001      SO45080          332         14657
# 1   1/1/2015   12/5/2001      SO45079          312         29255
# 2   1/1/2015  10/29/2001      SO45082          350         11455
# 3   1/1/2015  11/16/2001      SO45081          338         26782
# 4   1/2/2015  12/15/2001      SO45083          312         14947
#
#    territory_key  order_line_item  order_quantity  product_subcategory_key  \
# 0              1                1               1                        2
# 1              4                1               1                        2
# 2              9                1               1                        1
# 3              6                1               1                        2
# 4             10                1               1                        2
#
#   product_sku  ...    model_name  \
# 0  BK-R50B-58  ...      Road-650
# 1  BK-R93R-48  ...      Road-150
# 2  BK-M82B-44  ...  Mountain-100
# 3  BK-R50B-44  ...      Road-650
# 4  BK-R93R-48  ...      Road-150
#
#                                  product_description product_color  \
# 0  Value-priced bike with many features of our to...         Black
# 1  This bike is ridden by race winners. Developed...           Red
# 2  Top-of-the-line competition mountain bike. Per...         Black
# 3  Value-priced bike with many features of our to...         Black
# 4  This bike is ridden by race winners. Developed...           Red
#
#   product_size product_style product_cost  product_price  subcategory_name  \
# 0           58             U     413.1463       699.0982        Road Bikes
# 1           48             U    2171.2942      3578.2700        Road Bikes
# 2           44             U    1898.0944      3374.9900    Mountain Bikes
# 3           44             U     413.1463       699.0982        Road Bikes
# 4           48             U    2171.2942      3578.2700        Road Bikes
#
#   product_category_key  category_name
# 0                    1          Bikes
# 1                    1          Bikes
# 2                    1          Bikes
# 3                    1          Bikes
# 4                    1          Bikes
#
# [5 rows x 21 columns]

# %%
# By default the max number of rows displayed in pandas is 20, 
# since we have 21 columns, the first and last ten are currently shown

# Similarly the default number of characters is 50, so some values might be cut off

# We can force Pandas to show all of the columns using the following commands
pd.set_option('display.max_columns', 1000) # Now we will see up to 1000 columns
pd.set_option('display.max_colwidth', 1000) # And we will see up to 1000 characters in each column

# If we execute the .head() command again, we'll now see all of the data in the first 5 rows
sales_df.head()
# Out:
#   order_date  stock_date order_number  product_key  customer_key  \
# 0   1/1/2015   9/21/2001      SO45080          332         14657
# 1   1/1/2015   12/5/2001      SO45079          312         29255
# 2   1/1/2015  10/29/2001      SO45082          350         11455
# 3   1/1/2015  11/16/2001      SO45081          338         26782
# 4   1/2/2015  12/15/2001      SO45083          312         14947
#
#    territory_key  order_line_item  order_quantity  product_subcategory_key  \
# 0              1                1               1                        2
# 1              4                1               1                        2
# 2              9                1               1                        1
# 3              6                1               1                        2
# 4             10                1               1                        2
#
#   product_sku            product_name    model_name  \
# 0  BK-R50B-58      Road-650 Black, 58      Road-650
# 1  BK-R93R-48        Road-150 Red, 48      Road-150
# 2  BK-M82B-44  Mountain-100 Black, 44  Mountain-100
# 3  BK-R50B-44      Road-650 Black, 44      Road-650
# 4  BK-R93R-48        Road-150 Red, 48      Road-150
#
#                                                                                                                                                                                         product_description  \
# 0                                                         Value-priced bike with many features of our top-of-the-line models. Has the same light, stiff frame, and the quick acceleration we're famous for.
# 1  This bike is ridden by race winners. Developed with the Adventure Works Cycles professional race team, it has a extremely light heat-treated aluminum frame, and steering that allows precision control.
# 2                                    Top-of-the-line competition mountain bike. Performance-enhancing options include the innovative HL Frame, super-smooth front suspension, and traction for all terrain.
# 3                                                         Value-priced bike with many features of our top-of-the-line models. Has the same light, stiff frame, and the quick acceleration we're famous for.
# 4  This bike is ridden by race winners. Developed with the Adventure Works Cycles professional race team, it has a extremely light heat-treated aluminum frame, and steering that allows precision control.
#
#   product_color product_size product_style  product_cost  product_price  \
# 0         Black           58             U      413.1463       699.0982
# 1           Red           48             U     2171.2942      3578.2700
# 2         Black           44             U     1898.0944      3374.9900
# 3         Black           44             U      413.1463       699.0982
# 4           Red           48             U     2171.2942      3578.2700
#
#   subcategory_name  product_category_key category_name
# 0       Road Bikes                     1         Bikes
# 1       Road Bikes                     1         Bikes
# 2   Mountain Bikes                     1         Bikes
# 3       Road Bikes                     1         Bikes
# 4       Road Bikes                     1         Bikes

# %%
# To count the number of rows in a Pandas dataframe, we use the len() function
num_rows = len(sales_df)
print('The sales dataframe has %d rows' % num_rows)

# Pandas Index object can only handle hashable types
# To view the names of each column and to count their number, we use the .columns.to_list() function
col_names = sales_df.columns
print(col_names)
col_names = sales_df.columns.to_list()
num_cols = len(col_names)

print('The sales dataframe has %d columns' % num_cols)
print('Their names are: %s' % col_names)
# Out:
# The sales dataframe has 56046 rows
# Index(['order_date', 'stock_date', 'order_number', 'product_key',
#        'customer_key', 'territory_key', 'order_line_item', 'order_quantity',
#        'product_subcategory_key', 'product_sku', 'product_name', 'model_name',
#        'product_description', 'product_color', 'product_size', 'product_style',
#        'product_cost', 'product_price', 'subcategory_name',
#        'product_category_key', 'category_name'],
#       dtype='object')
# The sales dataframe has 21 columns
# Their names are: ['order_date', 'stock_date', 'order_number', 'product_key', 'customer_key', 'territory_key', 'order_line_item', 'order_quantity', 'product_subcategory_key', 'product_sku', 'product_name', 'model_name', 'product_description', 'product_color', 'product_size', 'product_style', 'product_cost', 'product_price', 'subcategory_name', 'product_category_key', 'category_name']

# %%
# To get the number of rows and columns in a single command, we can use .shape
df_shape = sales_df.shape # This returns a tuple with 2 values
print('The shape of the dataframe is: ', df_shape)

# The first value in the tuple is the number of rows, the second is the number of columns
num_rows, num_cols = df_shape
print('The dataframe has %d rows, and %d columns' % (num_rows, num_cols))
# Out:
# The shape of the dataframe is:  (56046, 21)
# The dataframe has 56046 rows, and 21 columns

# %%
# To select a single column, we can use a command with format: df['col_name']
# For example, if we want to select only the 'order_date' column, we can do
order_date_col = sales_df['order_date']
print(order_date_col) # Note, this column contains hash values in the anonymized dataset
# Out:
# 0         1/1/2015
# 1         1/1/2015
# 2         1/1/2015
# 3         1/1/2015
# 4         1/2/2015
#            ...
# 56041    6/30/2017
# 56042    6/30/2017
# 56043    6/30/2017
# 56044    6/30/2017
# 56045    6/30/2017
# Name: order_date, Length: 56046, dtype: object

# %%
# To select multiple columns, we can use a command with format: df[['col_name1', 'col_name2']]
# Note: We pass a list of column names inside the outer square brackets
# For example, we can do
cols = sales_df[['order_date', 'order_number']]
print(cols)
# Out:
#       order_date order_number
# 0       1/1/2015      SO45080
# 1       1/1/2015      SO45079
# 2       1/1/2015      SO45082
# 3       1/1/2015      SO45081
# 4       1/2/2015      SO45083
# ...          ...          ...
# 56041  6/30/2017      SO74143
# 56042  6/30/2017      SO74143
# 56043  6/30/2017      SO74143
# 56044  6/30/2017      SO74124
# 56045  6/30/2017      SO74124
#
# [56046 rows x 2 columns]

# %%
# Editing a Pandas DataFrame
# .loc[], .iloc[], .at[], .iat[]

# Select first 5 rows 

# Using Range

first_5_rows = sales_df.loc[range(5)]
first_5_rows
# Out:
#   order_date  stock_date order_number  product_key  customer_key  \
# 0   1/1/2015   9/21/2001      SO45080          332         14657
# 1   1/1/2015   12/5/2001      SO45079          312         29255
# 2   1/1/2015  10/29/2001      SO45082          350         11455
# 3   1/1/2015  11/16/2001      SO45081          338         26782
# 4   1/2/2015  12/15/2001      SO45083          312         14947
#
#    territory_key  order_line_item  order_quantity  product_subcategory_key  \
# 0              1                1               1                        2
# 1              4                1               1                        2
# 2              9                1               1                        1
# 3              6                1               1                        2
# 4             10                1               1                        2
#
#   product_sku            product_name    model_name  \
# 0  BK-R50B-58      Road-650 Black, 58      Road-650
# 1  BK-R93R-48        Road-150 Red, 48      Road-150
# 2  BK-M82B-44  Mountain-100 Black, 44  Mountain-100
# 3  BK-R50B-44      Road-650 Black, 44      Road-650
# 4  BK-R93R-48        Road-150 Red, 48      Road-150
#
#                                                                                                                                                                                         product_description  \
# 0                                                         Value-priced bike with many features of our top-of-the-line models. Has the same light, stiff frame, and the quick acceleration we're famous for.
# 1  This bike is ridden by race winners. Developed with the Adventure Works Cycles professional race team, it has a extremely light heat-treated aluminum frame, and steering that allows precision control.
# 2                                    Top-of-the-line competition mountain bike. Performance-enhancing options include the innovative HL Frame, super-smooth front suspension, and traction for all terrain.
# 3                                                         Value-priced bike with many features of our top-of-the-line models. Has the same light, stiff frame, and the quick acceleration we're famous for.
# 4  This bike is ridden by race winners. Developed with the Adventure Works Cycles professional race team, it has a extremely light heat-treated aluminum frame, and steering that allows precision control.
#
#   product_color product_size product_style  product_cost  product_price  \
# 0         Black           58             U      413.1463       699.0982
# 1           Red           48             U     2171.2942      3578.2700
# 2         Black           44             U     1898.0944      3374.9900
# 3         Black           44             U      413.1463       699.0982
# 4           Red           48             U     2171.2942      3578.2700
#
#   subcategory_name  product_category_key category_name
# 0       Road Bikes                     1         Bikes
# 1       Road Bikes                     1         Bikes
# 2   Mountain Bikes                     1         Bikes
# 3       Road Bikes                     1         Bikes
# 4       Road Bikes                     1         Bikes

# %%
# Select 5 rows in the middle of the data frame
# Using a slice

selection = sales_df.loc[100:105] # Note: this interval is inclusive of both ends and is equivalent to range(100,106)
selection
# Out:
#     order_date  stock_date order_number  product_key  customer_key  \
# 100  1/18/2015  11/30/2001      SO45180          311         15046
# 101  1/18/2015   10/1/2001      SO45184          320         25717
# 102  1/18/2015    1/1/2002      SO45183          334         25711
# 103  1/18/2015  10/25/2001      SO45181          310         14929
# 104  1/18/2015  12/11/2001      SO45185          310         14949
# 105  1/18/2015  10/25/2001      SO45182          312         18769
#
#      territory_key  order_line_item  order_quantity  product_subcategory_key  \
# 100             10                1               1                        2
# 101              9                1               1                        2
# 102              9                1               1                        2
# 103             10                1               1                        2
# 104             10                1               1                        2
# 105              9                1               1                        2
#
#     product_sku        product_name model_name  \
# 100  BK-R93R-44    Road-150 Red, 44   Road-150
# 101  BK-R50R-58    Road-650 Red, 58   Road-650
# 102  BK-R50B-60  Road-650 Black, 60   Road-650
# 103  BK-R93R-62    Road-150 Red, 62   Road-150
# 104  BK-R93R-62    Road-150 Red, 62   Road-150
# 105  BK-R93R-48    Road-150 Red, 48   Road-150
#
#                                                                                                                                                                                           product_description  \
# 100  This bike is ridden by race winners. Developed with the Adventure Works Cycles professional race team, it has a extremely light heat-treated aluminum frame, and steering that allows precision control.
# 101                                                         Value-priced bike with many features of our top-of-the-line models. Has the same light, stiff frame, and the quick acceleration we're famous for.
# 102                                                         Value-priced bike with many features of our top-of-the-line models. Has the same light, stiff frame, and the quick acceleration we're famous for.
# 103  This bike is ridden by race winners. Developed with the Adventure Works Cycles professional race team, it has a extremely light heat-treated aluminum frame, and steering that allows precision control.
# 104  This bike is ridden by race winners. Developed with the Adventure Works Cycles professional race team, it has a extremely light heat-treated aluminum frame, and steering that allows precision control.
# 105  This bike is ridden by race winners. Developed with the Adventure Works Cycles professional race team, it has a extremely light heat-treated aluminum frame, and steering that allows precision control.
#
#     product_color product_size product_style  product_cost  product_price  \
# 100           Red           44             U     2171.2942      3578.2700
# 101           Red           58             U      413.1463       699.0982
# 102         Black           60             U      413.1463       699.0982
# 103           Red           62             U     2171.2942      3578.2700
# 104           Red           62             U     2171.2942      3578.2700
# 105           Red           48             U     2171.2942      3578.2700
#
#     subcategory_name  product_category_key category_name
# 100       Road Bikes                     1         Bikes
# 101       Road Bikes                     1         Bikes
# 102       Road Bikes                     1         Bikes
# 103       Road Bikes                     1         Bikes
# 104       Road Bikes                     1         Bikes
# 105       Road Bikes                     1         Bikes

# %%
# Why end-inclusive slicing? Any thoughts?
df1 = pd.DataFrame([1, 2, 3, 4], columns = ['X'], index = ['a', 'b', 'c', 'd'])
df2 = pd.DataFrame([1, 2, 3, 4], columns = ['X'], index = ['a', 'b', 'c', 'x'])

print(df1.loc['b':'c'])
print(df2.loc['b':'c'])
# Out:
#    X
# b  2
# c  3
#    X
# b  2
# c  3

# %%
# Using lists to select rows and columns

selection = sales_df.loc[100:105, ['product_name', 'model_name']]
print(selection)

# This is equivalent to doing
selection = sales_df.loc[[100, 101, 102, 103, 104, 105], ['product_name', 'model_name']]
print(selection)

# And also equivalent to doing 
rows = [100, 101, 102, 103, 104, 105]
cols = ['product_name', 'model_name']
selection = sales_df.loc[rows, cols]
print(selection)
# Out:
#            product_name model_name
# 100    Road-150 Red, 44   Road-150
# 101    Road-650 Red, 58   Road-650
# 102  Road-650 Black, 60   Road-650
# 103    Road-150 Red, 62   Road-150
# 104    Road-150 Red, 62   Road-150
# 105    Road-150 Red, 48   Road-150
#            product_name model_name
# 100    Road-150 Red, 44   Road-150
# 101    Road-650 Red, 58   Road-650
# 102  Road-650 Black, 60   Road-650
# 103    Road-150 Red, 62   Road-150
# 104    Road-150 Red, 62   Road-150
# 105    Road-150 Red, 48   Road-150
#            product_name model_name
# 100    Road-150 Red, 44   Road-150
# 101    Road-650 Red, 58   Road-650
# 102  Road-650 Black, 60   Road-650
# 103    Road-150 Red, 62   Road-150
# 104    Road-150 Red, 62   Road-150
# 105    Road-150 Red, 48   Road-150

# %%
#### Exercise!
'''
How would I select rows with Indices [0, 5, 10, 15, 20] with .loc[]
1. Using range
2. Using slice
3. Using list
'''
# Out:
# '\nHow would I select rows with Indices [0, 5, 10, 15, 20] with .loc[]\n1. Using range\n2. Using slice\n3. Using list\n'

# %%
#### Exercise!
'''
How would I select rows with Indices [100, 105, 110, 115, 120] with .loc[] and columns 'order_date', 'product_name'
1. Using range
2. Using slice
3. Using list

# Use a list for the column names
'''
# Out:
# "\nHow would I select rows with Indices [100, 105, 110, 115, 120] with .loc[] and columns 'order_date', 'product_name'\n1. Using range\n2. Using slice\n3. Using list\n\n# Use a list for the column names\n"

# %%
# using .iloc[]

# Select first 5 rows using range

sales_df.iloc[range(6)]
# Out:
#   order_date  stock_date order_number  product_key  customer_key  \
# 0   1/1/2015   9/21/2001      SO45080          332         14657
# 1   1/1/2015   12/5/2001      SO45079          312         29255
# 2   1/1/2015  10/29/2001      SO45082          350         11455
# 3   1/1/2015  11/16/2001      SO45081          338         26782
# 4   1/2/2015  12/15/2001      SO45083          312         14947
# 5   1/2/2015  10/12/2001      SO45084          310         29143
#
#    territory_key  order_line_item  order_quantity  product_subcategory_key  \
# 0              1                1               1                        2
# 1              4                1               1                        2
# 2              9                1               1                        1
# 3              6                1               1                        2
# 4             10                1               1                        2
# 5              4                1               1                        2
#
#   product_sku            product_name    model_name  \
# 0  BK-R50B-58      Road-650 Black, 58      Road-650
# 1  BK-R93R-48        Road-150 Red, 48      Road-150
# 2  BK-M82B-44  Mountain-100 Black, 44  Mountain-100
# 3  BK-R50B-44      Road-650 Black, 44      Road-650
# 4  BK-R93R-48        Road-150 Red, 48      Road-150
# 5  BK-R93R-62        Road-150 Red, 62      Road-150
#
#                                                                                                                                                                                         product_description  \
# 0                                                         Value-priced bike with many features of our top-of-the-line models. Has the same light, stiff frame, and the quick acceleration we're famous for.
# 1  This bike is ridden by race winners. Developed with the Adventure Works Cycles professional race team, it has a extremely light heat-treated aluminum frame, and steering that allows precision control.
# 2                                    Top-of-the-line competition mountain bike. Performance-enhancing options include the innovative HL Frame, super-smooth front suspension, and traction for all terrain.
# 3                                                         Value-priced bike with many features of our top-of-the-line models. Has the same light, stiff frame, and the quick acceleration we're famous for.
# 4  This bike is ridden by race winners. Developed with the Adventure Works Cycles professional race team, it has a extremely light heat-treated aluminum frame, and steering that allows precision control.
# 5  This bike is ridden by race winners. Developed with the Adventure Works Cycles professional race team, it has a extremely light heat-treated aluminum frame, and steering that allows precision control.
#
#   product_color product_size product_style  product_cost  product_price  \
# 0         Black           58             U      413.1463       699.0982
# 1           Red           48             U     2171.2942      3578.2700
# 2         Black           44             U     1898.0944      3374.9900
# 3         Black           44             U      413.1463       699.0982
# 4           Red           48             U     2171.2942      3578.2700
# 5           Red           62             U     2171.2942      3578.2700
#
#   subcategory_name  product_category_key category_name
# 0       Road Bikes                     1         Bikes
# 1       Road Bikes                     1         Bikes
# 2   Mountain Bikes                     1         Bikes
# 3       Road Bikes                     1         Bikes
# 4       Road Bikes                     1         Bikes
# 5       Road Bikes                     1         Bikes

# %%
# Select 5 rows in the middle using a slice
sales_df.iloc[100:106]
# Out:
#     order_date  stock_date order_number  product_key  customer_key  \
# 100  1/18/2015  11/30/2001      SO45180          311         15046
# 101  1/18/2015   10/1/2001      SO45184          320         25717
# 102  1/18/2015    1/1/2002      SO45183          334         25711
# 103  1/18/2015  10/25/2001      SO45181          310         14929
# 104  1/18/2015  12/11/2001      SO45185          310         14949
# 105  1/18/2015  10/25/2001      SO45182          312         18769
#
#      territory_key  order_line_item  order_quantity  product_subcategory_key  \
# 100             10                1               1                        2
# 101              9                1               1                        2
# 102              9                1               1                        2
# 103             10                1               1                        2
# 104             10                1               1                        2
# 105              9                1               1                        2
#
#     product_sku        product_name model_name  \
# 100  BK-R93R-44    Road-150 Red, 44   Road-150
# 101  BK-R50R-58    Road-650 Red, 58   Road-650
# 102  BK-R50B-60  Road-650 Black, 60   Road-650
# 103  BK-R93R-62    Road-150 Red, 62   Road-150
# 104  BK-R93R-62    Road-150 Red, 62   Road-150
# 105  BK-R93R-48    Road-150 Red, 48   Road-150
#
#                                                                                                                                                                                           product_description  \
# 100  This bike is ridden by race winners. Developed with the Adventure Works Cycles professional race team, it has a extremely light heat-treated aluminum frame, and steering that allows precision control.
# 101                                                         Value-priced bike with many features of our top-of-the-line models. Has the same light, stiff frame, and the quick acceleration we're famous for.
# 102                                                         Value-priced bike with many features of our top-of-the-line models. Has the same light, stiff frame, and the quick acceleration we're famous for.
# 103  This bike is ridden by race winners. Developed with the Adventure Works Cycles professional race team, it has a extremely light heat-treated aluminum frame, and steering that allows precision control.
# 104  This bike is ridden by race winners. Developed with the Adventure Works Cycles professional race team, it has a extremely light heat-treated aluminum frame, and steering that allows precision control.
# 105  This bike is ridden by race winners. Developed with the Adventure Works Cycles professional race team, it has a extremely light heat-treated aluminum frame, and steering that allows precision control.
#
#     product_color product_size product_style  product_cost  product_price  \
# 100           Red           44             U     2171.2942      3578.2700
# 101           Red           58             U      413.1463       699.0982
# 102         Black           60             U      413.1463       699.0982
# 103           Red           62             U     2171.2942      3578.2700
# 104           Red           62             U     2171.2942      3578.2700
# 105           Red           48             U     2171.2942      3578.2700
#
#     subcategory_name  product_category_key category_name
# 100       Road Bikes                     1         Bikes
# 101       Road Bikes                     1         Bikes
# 102       Road Bikes                     1         Bikes
# 103       Road Bikes                     1         Bikes
# 104       Road Bikes                     1         Bikes
# 105       Road Bikes                     1         Bikes

# %%
# Using lists to select rows and columns

selection = sales_df.iloc[100:106, [0, 1]]
print(selection)

# This is equivalent to doing
selection = sales_df.iloc[[100, 101, 102, 103, 104, 105], [0, 1]]
print(selection)
# Out:
#     order_date  stock_date
# 100  1/18/2015  11/30/2001
# 101  1/18/2015   10/1/2001
# 102  1/18/2015    1/1/2002
# 103  1/18/2015  10/25/2001
# 104  1/18/2015  12/11/2001
# 105  1/18/2015  10/25/2001
#     order_date  stock_date
# 100  1/18/2015  11/30/2001
# 101  1/18/2015   10/1/2001
# 102  1/18/2015    1/1/2002
# 103  1/18/2015  10/25/2001
# 104  1/18/2015  12/11/2001
# 105  1/18/2015  10/25/2001

# %%
# Exercise with .iloc[]

'''
1. Get 'product_name' and 'model_name' for rows 10, 15 using .iloc[]
2. Get 'order_date', 'product_key' for rows 10, 15, 20 using slice for rows and list for columns
3. Get 'order_date', 'order_number', 'customer_key' for rows 100 to 105 (including 105) using range for rows and slice for columns
'''
# Out:
# "\n1. Get 'product_name' and 'model_name' for rows 10, 15 using .iloc[]\n2. Get 'order_date', 'product_key' for rows 10, 15, 20 using slice for rows and list for columns\n3. Get 'order_date', 'order_number', 'customer_key' for rows 100 to 105 (including 105) using range for rows and slice for columns\n"

# %%
# .at[] is optimized to return scalar values

sales_df.at[0, 'order_date']
# Out:
# '1/1/2015'

# %%
sales_df.iat[0, 0]
# Out:
# '1/1/2015'

# %%
# Exercise
'''
# Will this work?
# sales_df.at[0, ['order_date', 'product_key']]
'''
# Out:
# "\n# Will this work?\n# sales_df.at[0, ['order_date', 'product_key']]\n"

# %%
# Setting values with .loc[], .iloc[], .at[], .iat[]

sales_df.loc[0, 'order_date'] = '9/9/9'
sales_df.head(1)
# Out:
#   order_date stock_date order_number  product_key  customer_key  \
# 0      9/9/9  9/21/2001      SO45080          332         14657
#
#    territory_key  order_line_item  order_quantity  product_subcategory_key  \
# 0              1                1               1                        2
#
#   product_sku        product_name model_name  \
# 0  BK-R50B-58  Road-650 Black, 58   Road-650
#
#                                                                                                                                  product_description  \
# 0  Value-priced bike with many features of our top-of-the-line models. Has the same light, stiff frame, and the quick acceleration we're famous for.
#
#   product_color product_size product_style  product_cost  product_price  \
# 0         Black           58             U      413.1463       699.0982
#
#   subcategory_name  product_category_key category_name
# 0       Road Bikes                     1         Bikes

# %%
sales_df.loc[0, ['order_date', 'product_key']] = ['1/2/3', 123]
sales_df.head(1)
# Out:
#   order_date stock_date order_number  product_key  customer_key  \
# 0      1/2/3  9/21/2001      SO45080          123         14657
#
#    territory_key  order_line_item  order_quantity  product_subcategory_key  \
# 0              1                1               1                        2
#
#   product_sku        product_name model_name  \
# 0  BK-R50B-58  Road-650 Black, 58   Road-650
#
#                                                                                                                                  product_description  \
# 0  Value-priced bike with many features of our top-of-the-line models. Has the same light, stiff frame, and the quick acceleration we're famous for.
#
#   product_color product_size product_style  product_cost  product_price  \
# 0         Black           58             U      413.1463       699.0982
#
#   subcategory_name  product_category_key category_name
# 0       Road Bikes                     1         Bikes

# %%
sales_df.loc[0:1, ['order_date', 'product_key']] = [['1/2/3', 123], ['1/2/3', 123]]
sales_df.head(2)
# Out:
#   order_date stock_date order_number  product_key  customer_key  \
# 0      1/2/3  9/21/2001      SO45080          123         14657
# 1      1/2/3  12/5/2001      SO45079          123         29255
#
#    territory_key  order_line_item  order_quantity  product_subcategory_key  \
# 0              1                1               1                        2
# 1              4                1               1                        2
#
#   product_sku        product_name model_name  \
# 0  BK-R50B-58  Road-650 Black, 58   Road-650
# 1  BK-R93R-48    Road-150 Red, 48   Road-150
#
#                                                                                                                                                                                         product_description  \
# 0                                                         Value-priced bike with many features of our top-of-the-line models. Has the same light, stiff frame, and the quick acceleration we're famous for.
# 1  This bike is ridden by race winners. Developed with the Adventure Works Cycles professional race team, it has a extremely light heat-treated aluminum frame, and steering that allows precision control.
#
#   product_color product_size product_style  product_cost  product_price  \
# 0         Black           58             U      413.1463       699.0982
# 1           Red           48             U     2171.2942      3578.2700
#
#   subcategory_name  product_category_key category_name
# 0       Road Bikes                     1         Bikes
# 1       Road Bikes                     1         Bikes

# %%
sales_df.iloc[0, 0] = '19/19/19'
sales_df.head(1)
# Out:
#   order_date stock_date order_number  product_key  customer_key  \
# 0   19/19/19  9/21/2001      SO45080          123         14657
#
#    territory_key  order_line_item  order_quantity  product_subcategory_key  \
# 0              1                1               1                        2
#
#   product_sku        product_name model_name  \
# 0  BK-R50B-58  Road-650 Black, 58   Road-650
#
#                                                                                                                                  product_description  \
# 0  Value-priced bike with many features of our top-of-the-line models. Has the same light, stiff frame, and the quick acceleration we're famous for.
#
#   product_color product_size product_style  product_cost  product_price  \
# 0         Black           58             U      413.1463       699.0982
#
#   subcategory_name  product_category_key category_name
# 0       Road Bikes                     1         Bikes

# %%
# Exercise
'''
# sales_df.loc[0, ['order_date', 'product_key']] = ['1/2/3', 123]

How can we reproduce the above using .iloc[]

'''
# Out:
# "\n# sales_df.loc[0, ['order_date', 'product_key']] = ['1/2/3', 123]\n\nHow can we reproduce the above using .iloc[]\n\n"

# %%
sales_df.iloc[0:2, [0, 1]] = [['20/20/20', 'abc123'], ['20/20/20', 'abc123']]
sales_df.head(3)
# Out:
#   order_date  stock_date order_number  product_key  customer_key  \
# 0   20/20/20      abc123      SO45080          123         14657
# 1   20/20/20      abc123      SO45079          123         29255
# 2   1/1/2015  10/29/2001      SO45082          350         11455
#
#    territory_key  order_line_item  order_quantity  product_subcategory_key  \
# 0              1                1               1                        2
# 1              4                1               1                        2
# 2              9                1               1                        1
#
#   product_sku            product_name    model_name  \
# 0  BK-R50B-58      Road-650 Black, 58      Road-650
# 1  BK-R93R-48        Road-150 Red, 48      Road-150
# 2  BK-M82B-44  Mountain-100 Black, 44  Mountain-100
#
#                                                                                                                                                                                         product_description  \
# 0                                                         Value-priced bike with many features of our top-of-the-line models. Has the same light, stiff frame, and the quick acceleration we're famous for.
# 1  This bike is ridden by race winners. Developed with the Adventure Works Cycles professional race team, it has a extremely light heat-treated aluminum frame, and steering that allows precision control.
# 2                                    Top-of-the-line competition mountain bike. Performance-enhancing options include the innovative HL Frame, super-smooth front suspension, and traction for all terrain.
#
#   product_color product_size product_style  product_cost  product_price  \
# 0         Black           58             U      413.1463       699.0982
# 1           Red           48             U     2171.2942      3578.2700
# 2         Black           44             U     1898.0944      3374.9900
#
#   subcategory_name  product_category_key category_name
# 0       Road Bikes                     1         Bikes
# 1       Road Bikes                     1         Bikes
# 2   Mountain Bikes                     1         Bikes

# %%
# For example, if we want to edit the order_date of the 1st row, we can do
sales_df.at[0, 'order_date'] = '12/12/3000'
# Let's make sure that worked
sales_df.head(1)
# Out:
#    order_date stock_date order_number  product_key  customer_key  \
# 0  12/12/3000     abc123      SO45080          123         14657
#
#    territory_key  order_line_item  order_quantity  product_subcategory_key  \
# 0              1                1               1                        2
#
#   product_sku        product_name model_name  \
# 0  BK-R50B-58  Road-650 Black, 58   Road-650
#
#                                                                                                                                  product_description  \
# 0  Value-priced bike with many features of our top-of-the-line models. Has the same light, stiff frame, and the quick acceleration we're famous for.
#
#   product_color product_size product_style  product_cost  product_price  \
# 0         Black           58             U      413.1463       699.0982
#
#   subcategory_name  product_category_key category_name
# 0       Road Bikes                     1         Bikes

# %%
# The same thing works with .at[] as well
sales_df.at[0, ['order_date', 'product_key']] = ['1/2/3', 123]
sales_df
# Out:
#       order_date  stock_date order_number  product_key  customer_key  \
# 0          1/2/3      abc123      SO45080          123         14657
# 1       20/20/20      abc123      SO45079          123         29255
# 2       1/1/2015  10/29/2001      SO45082          350         11455
# 3       1/1/2015  11/16/2001      SO45081          338         26782
# 4       1/2/2015  12/15/2001      SO45083          312         14947
# ...          ...         ...          ...          ...           ...
# 56041  6/30/2017   3/22/2004      SO74143          477         28517
# 56042  6/30/2017   3/15/2004      SO74143          479         28517
# 56043  6/30/2017    4/8/2004      SO74143          606         28517
# 56044  6/30/2017   5/15/2004      SO74124          480         21676
# 56045  6/30/2017    5/4/2004      SO74124          538         21676
#
#        territory_key  order_line_item  order_quantity  \
# 0                  1                1               1
# 1                  4                1               1
# 2                  9                1               1
# 3                  6                1               1
# 4                 10                1               1
# ...              ...              ...             ...
# 56041             10                3               2
# 56042             10                2               1
# 56043             10                1               1
# 56044              7                2               2
# 56045              7                1               2
#
#        product_subcategory_key product_sku            product_name  \
# 0                            2  BK-R50B-58      Road-650 Black, 58
# 1                            2  BK-R93R-48        Road-150 Red, 48
# 2                            1  BK-M82B-44  Mountain-100 Black, 44
# 3                            2  BK-R50B-44      Road-650 Black, 44
# 4                            2  BK-R93R-48        Road-150 Red, 48
# ...                        ...         ...                     ...
# 56041                       28     WB-H098   Water Bottle - 30 oz.
# 56042                       28     BC-R205        Road Bottle Cage
# 56043                        2  BK-R19B-52      Road-750 Black, 52
# 56044                       37     PK-7098     Patch Kit/8 Patches
# 56045                       37     TI-R092            LL Road Tire
#
#              model_name  \
# 0              Road-650
# 1              Road-150
# 2          Mountain-100
# 3              Road-650
# 4              Road-150
# ...                 ...
# 56041      Water Bottle
# 56042  Road Bottle Cage
# 56043          Road-750
# 56044         Patch kit
# 56045      LL Road Tire
#
#                                                                                                                                                                                             product_description  \
# 0                                                             Value-priced bike with many features of our top-of-the-line models. Has the same light, stiff frame, and the quick acceleration we're famous for.
# 1      This bike is ridden by race winners. Developed with the Adventure Works Cycles professional race team, it has a extremely light heat-treated aluminum frame, and steering that allows precision control.
# 2                                        Top-of-the-line competition mountain bike. Performance-enhancing options include the innovative HL Frame, super-smooth front suspension, and traction for all terrain.
# 3                                                             Value-priced bike with many features of our top-of-the-line models. Has the same light, stiff frame, and the quick acceleration we're famous for.
# 4      This bike is ridden by race winners. Developed with the Adventure Works Cycles professional race team, it has a extremely light heat-treated aluminum frame, and steering that allows precision control.
# ...                                                                                                                                                                                                         ...
# 56041                                                                                                                                                          AWC logo water bottle - holds 30 oz; leak-proof.
# 56042                                                                                                                      Aluminum cage is lighter than our mountain version; perfect for long distance trips.
# 56043                                                                                           Entry level adult bike; offers a comfortable ride cross-country or down the block. Quick-release hubs and rims.
# 56044                                                                                                                                                    Includes 8 different size patches, glue and sandpaper.
# 56045                                                                                                                          Same great treads as more expensive tire with a less expensive wire bead casing.
#
#       product_color product_size product_style  product_cost  product_price  \
# 0             Black           58             U      413.1463       699.0982
# 1               Red           48             U     2171.2942      3578.2700
# 2             Black           44             U     1898.0944      3374.9900
# 3             Black           44             U      413.1463       699.0982
# 4               Red           48             U     2171.2942      3578.2700
# ...             ...          ...           ...           ...            ...
# 56041           NaN            0             0        1.8663         4.9900
# 56042           NaN            0             0        3.3623         8.9900
# 56043         Black           52             U      343.6496       539.9900
# 56044           NaN            0             0        0.8565         2.2900
# 56045           NaN            0             0        8.0373        21.4900
#
#         subcategory_name  product_category_key category_name
# 0             Road Bikes                     1         Bikes
# 1             Road Bikes                     1         Bikes
# 2         Mountain Bikes                     1         Bikes
# 3             Road Bikes                     1         Bikes
# 4             Road Bikes                     1         Bikes
# ...                  ...                   ...           ...
# 56041  Bottles and Cages                     4   Accessories
# 56042  Bottles and Cages                     4   Accessories
# 56043         Road Bikes                     1         Bikes
# 56044    Tires and Tubes                     4   Accessories
# 56045    Tires and Tubes                     4   Accessories
#
# [56046 rows x 21 columns]

# %%
# Exercise

'''
Can I do this?
1. sales_df.loc[0, 5:7]
2. sales_df.iat[0, [0, 1]] = ['1/2/3', 'abc123']
3. sales_df.at[0, ['order_date', 'territory_key']]
'''
# Out:
# "\nCan I do this?\n1. sales_df.loc[0, 5:7]\n2. sales_df.iat[0, [0, 1]] = ['1/2/3', 'abc123']\n3. sales_df.at[0, ['order_date', 'territory_key']]\n"

# %%
# Exercise

'''
# What should I replace ... with to edit the columns 'territory_key', 'order_line_item' and 'order_quantity'
# sales_df.loc[0, ...] = [9, 9, 9]
'''

# sales_df.head(1)
# Out:
# "\n# What should I replace ... with to edit the columns 'territory_key', 'order_line_item' and 'order_quantity'\n# sales_df.loc[0, ...] = [9, 9, 9]\n"

# %%
# Exercise
'''
Use .iloc[] to change the order date on the second row to 9/11/9
'''
# Out:
# '\nUse .iloc[] to change the order date on the second row to 9/11/9\n'

# %%
# Here's an example where we change a value based on its current value
current_value = sales_df.loc[5, 'subcategory_name']
print('Current value:', current_value)

# Who can tell what this line is doing?
new_value = '-'.join(current_value.lower().split()) 
sales_df.at[5, 'subcategory_name'] = new_value

# Again, let's make sure that worked
sales_df.loc[5, 'subcategory_name']
# Out:
# Current value: Road Bikes
# 'road-bikes'

# %%
### Exercise 

'''
Using .loc[], update the dataframe by adding 10 to all even rows between 0 and 10 to the column 'order_quantity'
'''
# Out:
# "\nUsing .loc[], update the dataframe by adding 10 to all even rows between 0 and 10 to the column 'order_quantity'\n"

# %%
# Finding rows based on column value

# Find rows with order_quantity 1

sales_df[sales_df['order_quantity'] == 1]
# Out:
#       order_date  stock_date order_number  product_key  customer_key  \
# 0          1/2/3      abc123      SO45080          123         14657
# 1       20/20/20      abc123      SO45079          123         29255
# 2       1/1/2015  10/29/2001      SO45082          350         11455
# 3       1/1/2015  11/16/2001      SO45081          338         26782
# 4       1/2/2015  12/15/2001      SO45083          312         14947
# ...          ...         ...          ...          ...           ...
# 56035  6/30/2017    4/4/2004      SO74130          486         21266
# 56038  6/30/2017   4/11/2004      SO74105          215         20223
# 56039  6/30/2017   3/28/2004      SO74105          229         20223
# 56042  6/30/2017   3/15/2004      SO74143          479         28517
# 56043  6/30/2017    4/8/2004      SO74143          606         28517
#
#        territory_key  order_line_item  order_quantity  \
# 0                  1                1               1
# 1                  4                1               1
# 2                  9                1               1
# 3                  6                1               1
# 4                 10                1               1
# ...              ...              ...             ...
# 56035              6                3               1
# 56038              9                3               1
# 56039              9                4               1
# 56042             10                2               1
# 56043             10                1               1
#
#        product_subcategory_key product_sku                product_name  \
# 0                            2  BK-R50B-58          Road-650 Black, 58
# 1                            2  BK-R93R-48            Road-150 Red, 48
# 2                            1  BK-M82B-44      Mountain-100 Black, 44
# 3                            2  BK-R50B-44          Road-650 Black, 44
# 4                            2  BK-R93R-48            Road-150 Red, 48
# ...                        ...         ...                         ...
# 56035                       27     ST-1401      All-Purpose Bike Stand
# 56038                       31     HL-U509     Sport-100 Helmet, Black
# 56039                       21   LJ-0192-M  Long-Sleeve Logo Jersey, M
# 56042                       28     BC-R205            Road Bottle Cage
# 56043                        2  BK-R19B-52          Road-750 Black, 52
#
#                     model_name  \
# 0                     Road-650
# 1                     Road-150
# 2                 Mountain-100
# 3                     Road-650
# 4                     Road-150
# ...                        ...
# 56035   All-Purpose Bike Stand
# 56038                Sport-100
# 56039  Long-Sleeve Logo Jersey
# 56042         Road Bottle Cage
# 56043                 Road-750
#
#                                                                                                                                                                                             product_description  \
# 0                                                             Value-priced bike with many features of our top-of-the-line models. Has the same light, stiff frame, and the quick acceleration we're famous for.
# 1      This bike is ridden by race winners. Developed with the Adventure Works Cycles professional race team, it has a extremely light heat-treated aluminum frame, and steering that allows precision control.
# 2                                        Top-of-the-line competition mountain bike. Performance-enhancing options include the innovative HL Frame, super-smooth front suspension, and traction for all terrain.
# 3                                                             Value-priced bike with many features of our top-of-the-line models. Has the same light, stiff frame, and the quick acceleration we're famous for.
# 4      This bike is ridden by race winners. Developed with the Adventure Works Cycles professional race team, it has a extremely light heat-treated aluminum frame, and steering that allows precision control.
# ...                                                                                                                                                                                                         ...
# 56035                                                                                           Perfect all-purpose bike stand for working on your bike at home. Quick-adjusting clamps and steel construction.
# 56038                                                                                                                                                  Universal fit, well-vented, lightweight , snap-on visor.
# 56039                                                                                                                                                     Unisex long-sleeve AWC logo microfiber cycling jersey
# 56042                                                                                                                      Aluminum cage is lighter than our mountain version; perfect for long distance trips.
# 56043                                                                                           Entry level adult bike; offers a comfortable ride cross-country or down the block. Quick-release hubs and rims.
#
#       product_color product_size product_style  product_cost  product_price  \
# 0             Black           58             U      413.1463       699.0982
# 1               Red           48             U     2171.2942      3578.2700
# 2             Black           44             U     1898.0944      3374.9900
# 3             Black           44             U      413.1463       699.0982
# 4               Red           48             U     2171.2942      3578.2700
# ...             ...          ...           ...           ...            ...
# 56035           NaN            0             0       59.4660       159.0000
# 56038         Black            0             0       12.0278        33.6442
# 56039         Multi            M             U       31.7244        48.0673
# 56042           NaN            0             0        3.3623         8.9900
# 56043         Black           52             U      343.6496       539.9900
#
#         subcategory_name  product_category_key category_name
# 0             Road Bikes                     1         Bikes
# 1             Road Bikes                     1         Bikes
# 2         Mountain Bikes                     1         Bikes
# 3             Road Bikes                     1         Bikes
# 4             Road Bikes                     1         Bikes
# ...                  ...                   ...           ...
# 56035        Bike Stands                     4   Accessories
# 56038            Helmets                     4   Accessories
# 56039            Jerseys                     3      Clothing
# 56042  Bottles and Cages                     4   Accessories
# 56043         Road Bikes                     1         Bikes
#
# [31421 rows x 21 columns]

# %%
# Data can be saved from a Pandas dataframe to a variety of file types
# Similar to loading, we'll focus on 2 types: csv files and pickle files 

# There are both pros and cons of saving dataframe to CSV files
# Pros: Will be essentially a text file which can be opened with a text editor or excel.
# Cons: Variable types can be lost (ex: integer, float, string, dates). Not convenient if 
# the dataframe contains complex types such as lists, dictionaries, images, etc...

# Similar to loading from a CSV file, we first define a filepath, and then use a function to save
# Note: We've made some changes to the original dataframe, so be sure to save to a NEW FILE

new_csv_file_path = './data/sales_data_all_edited.csv'
sales_df.to_csv(path_or_buf=new_csv_file_path, header=True, index=False, sep=',')

# sales_df.to_csv(new_csv_file_path, index = False)

# %%
# Pickle files are best practice
# This will create a binary file that keeps all the attributes of the data 
# (including date, number, string types, NAs, etc...).

# Similar to loading from a pickle file, we first define a filepath, and then open the file, then dump the data
# Note: We've made some changes to the original dataframe, so be sure to save to a NEW FILE

new_pickle_file_path = './data/sales_data_all_edited.pickle'
sales_df.to_pickle(new_pickle_file_path)

# %%
original_data = pd.read_csv('./data/sales_data_all.csv')
pickled_data = pd.read_pickle('./data/sales_data_all_edited.pickle')

print("Original : \n", original_data.iloc[:5, :5])
print("Pickled : \n", pickled_data.iloc[:5, :5])
# Out:
# Original :
#    order_date  stock_date order_number  product_key  customer_key
# 0   1/1/2015   9/21/2001      SO45080          332         14657
# 1   1/1/2015   12/5/2001      SO45079          312         29255
# 2   1/1/2015  10/29/2001      SO45082          350         11455
# 3   1/1/2015  11/16/2001      SO45081          338         26782
# 4   1/2/2015  12/15/2001      SO45083          312         14947
# Pickled :
#    order_date  stock_date order_number  product_key  customer_key
# 0      1/2/3      abc123      SO45080          123         14657
# 1   20/20/20      abc123      SO45079          123         29255
# 2   1/1/2015  10/29/2001      SO45082          350         11455
# 3   1/1/2015  11/16/2001      SO45081          338         26782
# 4   1/2/2015  12/15/2001      SO45083          312         14947

# %%
# Sometimes it is useful to loop over many rows in a dataframe
# Note: There are almost always more efficient ways to access / edit dataframe values
#       And we will cover many of those techniques in the next module. However it is still good to know
#       how to loop. See this forum post for more details:
#       https://stackoverflow.com/questions/16476924/how-to-iterate-over-rows-in-a-dataframe-in-pandas/55557758#55557758

# To loop over rows in a dataframe, we can use the .iterrows() function in a for loop
# This function is similar to the enumerate() function we've used before on lists
# Inside the loop, we have access to both the row index and the row values

# Let's take a look at what we can access for a single row
# Note: We can chain the .iterrows() function at the end of another function like .head()

for index, row in sales_df.head(1).iterrows():
    print('Index: %d' % index)
    print('Row:')
    print(row)

# We can easily access individual column values on each iteration
for index, row in sales_df.head(5).iterrows():
    print(row['order_date'])
# Out:
# Index: 0
# Row:
# order_date                                                                                                                                                             1/2/3
# stock_date                                                                                                                                                            abc123
# order_number                                                                                                                                                         SO45080
# product_key                                                                                                                                                              123
# customer_key                                                                                                                                                           14657
# territory_key                                                                                                                                                              1
# order_line_item                                                                                                                                                            1
# order_quantity                                                                                                                                                             1
# product_subcategory_key                                                                                                                                                    2
# product_sku                                                                                                                                                       BK-R50B-58
# product_name                                                                                                                                              Road-650 Black, 58
# model_name                                                                                                                                                          Road-650
# product_description        Value-priced bike with many features of our top-of-the-line models. Has the same light, stiff frame, and the quick acceleration we're famous for.
# product_color                                                                                                                                                          Black
# product_size                                                                                                                                                              58
# product_style                                                                                                                                                              U
# product_cost                                                                                                                                                         413.146
# product_price                                                                                                                                                        699.098
# subcategory_name                                                                                                                                                  Road Bikes
# product_category_key                                                                                                                                                       1
# category_name                                                                                                                                                          Bikes
# Name: 0, dtype: object
# 1/2/3
# 20/20/20
# 1/1/2015
# 1/1/2015
# 1/2/2015

# %%
# Note: During the looping, we are accessing copies of the original dataframe rows
# This means that if we try to assign new values to the row, the original dataframe will not be updated
# For example, let's look at several values before we loop
print(sales_df.loc[0:4, 'order_quantity'])

# Now we will loop and INCORRECTLY update the values
for index, row in sales_df.head(5).iterrows():
    row['order_quantity'] = row['order_quantity'] + 10

# To confirm that the update did not work
print(sales_df.loc[0:4, 'order_quantity'])
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: order_quantity, dtype: int64
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: order_quantity, dtype: int64

# %%
# However, we can use the .at[] command we just learned inside the loop to correctly perform updates
# Let's try that again:
print(sales_df.loc[0:4, 'order_quantity'])
for index, row in sales_df.head(5).iterrows():
    sales_df.at[index, 'order_quantity'] = row['order_quantity'] + 10 # Note: We use the index value to select the original row
# To confirm that the update did work
print(sales_df.loc[0:4, 'order_quantity'])
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: order_quantity, dtype: int64
# 0    11
# 1    11
# 2    11
# 3    11
# 4    11
# Name: order_quantity, dtype: int64

# %%
# One more example of looping
# We will loop through all the rows and count the number of times a particular condition is met
# In the next module, we will show how to perform the same computation in a fraction of the time
import time
col = 'territory_key'
threshold = 7
count = 0
start_time = time.time() # Start a timer
for index, row in sales_df.iterrows():
    if row[col] > threshold:
        count += 1
end_time = time.time() # End the timer
print('%s exceeded %.2f a total of %d times' % (col, threshold, count))
print('Computation took %.2f seconds' % (end_time - start_time))

# %%
# Exercise

'''
Using .iloc[], add 100 to the order quantity of all even rows
'''

# %%
# To change the names of 1 or more columns, we first build a dictionary
# The dictionary has key:value pairs that are old_value:new_value
rename_dict = {'order_date': 'edited_col_1', 'stock_date': 'edited_col_2'}

# If we want to create a new dataframe (copy of original) and then change to column names, we can do
renamed_sales_df = sales_df.rename(rename_dict, axis=1) # Axis 1 means columns, Axis 0 can be used for rows

# Let's confirm that the new dataframe has the new column names
new_cols = renamed_sales_df.columns.to_list()
print(new_cols)

# If we want to edit the column names in the original dataframe, we can use inplace=True in the function call
sales_df.rename(rename_dict, axis=1, inplace=True) # Note: This is done in place, so we do not use an assignment statement

# Let's confirm that the original dataframe has the new column names
new_cols = sales_df.columns.to_list()
print(new_cols)

# %%
### Exercise
'''
Rename the first 3 indices to 'a', 'b', 'c' in a new dataframe
'''

# %%
# Adding a new column is similar to adding a new key:value pair in a dictionary
sales_df['new_col_1'] = 'new_value' # Note: This will place a 'new_value' string in every row of the dataframe
print(sales_df['new_col_1'])

# We can also add a new column with a list of value
# Note: It is important that the length of the list matches the number of rows in the dataframe
num_rows = len(sales_df)
sales_df['new_col_2'] = [x * 2 for x in range(num_rows)] # Who can tell what this is adding to the new column?
print(sales_df['new_col_2'])

# # We can drop 1 or more columns using the .drop() function
sales_df.drop(['new_col_1', 'new_col_2'], axis=1, inplace=True) # Again, we use inplace=True

# We can also use - copy created
# sales_df.drop(columns = ['new_col_1', 'new_col_2'])

# Let's confirm that worked
print(sales_df.columns.to_list())

# %%
########################
# ACTIVITIES
########################
# Now, let's have some fun :)
########################

##########
# 5.1 ACTIVITY 1
##########

# 1. Load the original 'sales_data_all.pickle' file into a Pandas dataframe 
# 2. For the first and last row, print the values in the following columns:
#    'order_number', 'customer_key', 'model_name', and 'subcategory_name'
# 3. Now, for rows with index 20, 200, 2000, and 20000, print the values in the same 4 columns
# 4. Update rows 1, 4, 7, 10 using range and .iloc[] with the values [ABCD, 1234, Patch kit, Tires & Tubes]

###
# YOUR CODE HERE

###

# %%
##########s
# 5.2 ACTIVITY 2
##########

# 1. Use the same Pandas dataframe as in Activity 5.1
# 2. Determine how many rows have the same value for both 'order_line_item' and 'order_quantity'
#    Also, determine what percentage of total rows this value is
# 3. Determine how many rows have the same value for both 'product_category_key' and 'product_subcategory_key'
#    Also, determine what percentage of total rows this value is
###
# YOUR CODE HERE



###

# Correct results for step 2: 26262 (46.86%)
# Correct results for step 3: 4706  (08.39%)
